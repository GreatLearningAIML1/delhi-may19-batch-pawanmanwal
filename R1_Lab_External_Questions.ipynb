# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
iris=pd.read_csv('/content/drive/My Drive/Colab Notebooks/R1L2/Iris_external.csv')
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#Top 10
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
# 5                   5.4                  3.9  ...                  0.4  Iris-setosa
# 6                   4.6                  3.4  ...                  0.3  Iris-setosa
# 7                   5.0                  3.4  ...                  0.2  Iris-setosa
# 8                   4.4                  2.9  ...                  0.2  Iris-setosa
# 9                   4.9                  3.1  ...                  0.1  Iris-setosa
#
# [10 rows x 5 columns]

# %%
#Bottom 10
iris.tail(10)
# Out:
#      Sepal Length (in cm)  ...           Class
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
#iris.set_index('Sepal Length (in cm)',inplace=True)
iris.set_index('Sepal Length (in cm)')
# Out:
#                       Sepal Width in (cm)  ...           Class
# Sepal Length (in cm)                       ...
# 5.1                                   3.5  ...     Iris-setosa
# 4.9                                   3.0  ...     Iris-setosa
# 4.7                                   3.2  ...     Iris-setosa
# 4.6                                   3.1  ...     Iris-setosa
# 5.0                                   3.6  ...     Iris-setosa
# 5.4                                   3.9  ...     Iris-setosa
# 4.6                                   3.4  ...     Iris-setosa
# 5.0                                   3.4  ...     Iris-setosa
# 4.4                                   2.9  ...     Iris-setosa
# 4.9                                   3.1  ...     Iris-setosa
# 5.4                                   3.7  ...     Iris-setosa
# 4.8                                   3.4  ...     Iris-setosa
# 4.8                                   3.0  ...     Iris-setosa
# 4.3                                   3.0  ...     Iris-setosa
# 5.8                                   4.0  ...     Iris-setosa
# 5.7                                   4.4  ...     Iris-setosa
# 5.4                                   3.9  ...     Iris-setosa
# 5.1                                   3.5  ...     Iris-setosa
# 5.7                                   3.8  ...     Iris-setosa
# 5.1                                   3.8  ...     Iris-setosa
# 5.4                                   3.4  ...     Iris-setosa
# 5.1                                   3.7  ...     Iris-setosa
# 4.6                                   3.6  ...     Iris-setosa
# 5.1                                   3.3  ...     Iris-setosa
# 4.8                                   3.4  ...     Iris-setosa
# 5.0                                   3.0  ...     Iris-setosa
# 5.0                                   3.4  ...     Iris-setosa
# 5.2                                   3.5  ...     Iris-setosa
# 5.2                                   3.4  ...     Iris-setosa
# 4.7                                   3.2  ...     Iris-setosa
# ...                                   ...  ...             ...
# 6.9                                   3.2  ...  Iris-virginica
# 5.6                                   2.8  ...  Iris-virginica
# 7.7                                   2.8  ...  Iris-virginica
# 6.3                                   2.7  ...  Iris-virginica
# 6.7                                   3.3  ...  Iris-virginica
# 7.2                                   3.2  ...  Iris-virginica
# 6.2                                   2.8  ...  Iris-virginica
# 6.1                                   3.0  ...  Iris-virginica
# 6.4                                   2.8  ...  Iris-virginica
# 7.2                                   3.0  ...  Iris-virginica
# 7.4                                   2.8  ...  Iris-virginica
# 7.9                                   3.8  ...  Iris-virginica
# 6.4                                   2.8  ...  Iris-virginica
# 6.3                                   2.8  ...  Iris-virginica
# 6.1                                   2.6  ...  Iris-virginica
# 7.7                                   3.0  ...  Iris-virginica
# 6.3                                   3.4  ...  Iris-virginica
# 6.4                                   3.1  ...  Iris-virginica
# 6.0                                   3.0  ...  Iris-virginica
# 6.9                                   3.1  ...  Iris-virginica
# 6.7                                   3.1  ...  Iris-virginica
# 6.9                                   3.1  ...  Iris-virginica
# 5.8                                   2.7  ...  Iris-virginica
# 6.8                                   3.2  ...  Iris-virginica
# 6.7                                   3.3  ...  Iris-virginica
# 6.7                                   3.0  ...  Iris-virginica
# 6.3                                   2.5  ...  Iris-virginica
# 6.5                                   3.0  ...  Iris-virginica
# 6.2                                   3.4  ...  Iris-virginica
# 5.9                                   3.0  ...  Iris-virginica
#
# [150 rows x 4 columns]

# %%
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.head(5)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
iris.iloc[0:10][['Sepal Length (in cm)','Sepal Width in (cm)']]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris.loc[iris['Class'] == 'Iris-setosa']
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                    5.1                  3.5  ...                  0.2  Iris-setosa
# 1                    4.9                  3.0  ...                  0.2  Iris-setosa
# 2                    4.7                  3.2  ...                  0.2  Iris-setosa
# 3                    4.6                  3.1  ...                  0.2  Iris-setosa
# 4                    5.0                  3.6  ...                  0.2  Iris-setosa
# 5                    5.4                  3.9  ...                  0.4  Iris-setosa
# 6                    4.6                  3.4  ...                  0.3  Iris-setosa
# 7                    5.0                  3.4  ...                  0.2  Iris-setosa
# 8                    4.4                  2.9  ...                  0.2  Iris-setosa
# 9                    4.9                  3.1  ...                  0.1  Iris-setosa
# 10                   5.4                  3.7  ...                  0.2  Iris-setosa
# 11                   4.8                  3.4  ...                  0.2  Iris-setosa
# 12                   4.8                  3.0  ...                  0.1  Iris-setosa
# 13                   4.3                  3.0  ...                  0.1  Iris-setosa
# 14                   5.8                  4.0  ...                  0.2  Iris-setosa
# 15                   5.7                  4.4  ...                  0.4  Iris-setosa
# 16                   5.4                  3.9  ...                  0.4  Iris-setosa
# 17                   5.1                  3.5  ...                  0.3  Iris-setosa
# 18                   5.7                  3.8  ...                  0.3  Iris-setosa
# 19                   5.1                  3.8  ...                  0.3  Iris-setosa
# 20                   5.4                  3.4  ...                  0.2  Iris-setosa
# 21                   5.1                  3.7  ...                  0.4  Iris-setosa
# 22                   4.6                  3.6  ...                  0.2  Iris-setosa
# 23                   5.1                  3.3  ...                  0.5  Iris-setosa
# 24                   4.8                  3.4  ...                  0.2  Iris-setosa
# 25                   5.0                  3.0  ...                  0.2  Iris-setosa
# 26                   5.0                  3.4  ...                  0.4  Iris-setosa
# 27                   5.2                  3.5  ...                  0.2  Iris-setosa
# 28                   5.2                  3.4  ...                  0.2  Iris-setosa
# 29                   4.7                  3.2  ...                  0.2  Iris-setosa
# 30                   4.8                  3.1  ...                  0.2  Iris-setosa
# 31                   5.4                  3.4  ...                  0.4  Iris-setosa
# 32                   5.2                  4.1  ...                  0.1  Iris-setosa
# 33                   5.5                  4.2  ...                  0.2  Iris-setosa
# 34                   4.9                  3.1  ...                  0.1  Iris-setosa
# 35                   5.0                  3.2  ...                  0.2  Iris-setosa
# 36                   5.5                  3.5  ...                  0.2  Iris-setosa
# 37                   4.9                  3.1  ...                  0.1  Iris-setosa
# 38                   4.4                  3.0  ...                  0.2  Iris-setosa
# 39                   5.1                  3.4  ...                  0.2  Iris-setosa
# 40                   5.0                  3.5  ...                  0.3  Iris-setosa
# 41                   4.5                  2.3  ...                  0.3  Iris-setosa
# 42                   4.4                  3.2  ...                  0.2  Iris-setosa
# 43                   5.0                  3.5  ...                  0.6  Iris-setosa
# 44                   5.1                  3.8  ...                  0.4  Iris-setosa
# 45                   4.8                  3.0  ...                  0.3  Iris-setosa
# 46                   5.1                  3.8  ...                  0.2  Iris-setosa
# 47                   4.6                  3.2  ...                  0.2  Iris-setosa
# 48                   5.3                  3.7  ...                  0.2  Iris-setosa
# 49                   5.0                  3.3  ...                  0.2  Iris-setosa
#
# [50 rows x 5 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra'] = iris['Sepal Length (in cm)'] * iris['Sepal Width in (cm)']

# %%
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...        Class  SepalExtra
# 0                   5.1                  3.5  ...  Iris-setosa       17.85
# 1                   4.9                  3.0  ...  Iris-setosa       14.70
# 2                   4.7                  3.2  ...  Iris-setosa       15.04
# 3                   4.6                  3.1  ...  Iris-setosa       14.26
# 4                   5.0                  3.6  ...  Iris-setosa       18.00
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
iris.var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def sum2(a,b):
  total=a + b
  return total

# %%
iris.iloc[4,0]
iris.iloc[4,1]
sum2(iris.iloc[4,0], iris.iloc[4,1])
# Out:
# 8.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
iris.head(2)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...        Class  SepalExtra
# 0                   5.1                  3.5  ...  Iris-setosa       17.85
# 1                   4.9                  3.0  ...  Iris-setosa       14.70
#
# [2 rows x 6 columns]

# %%
#iris[iris['class']=='Iris-setosa']
#iris.loc[iris['Class']=='Iris-setosa'].loc[iris['Class']=='Sepal Length (in cm)']
#iris['Sepal Length (in cm)'].max()-iris['Sepal Length (in cm)'].min()
#iris.dtypes
irisFloatSet = iris[['Sepal Length (in cm)','Sepal Width in (cm)','Petal length (in cm)','Petal width (in cm)']]
#Range for all the columns
irisFloatSet.max()-irisFloatSet.min()
# Out:
# Sepal Length (in cm)    3.6
# Sepal Width in (cm)     2.4
# Petal length (in cm)    5.9
# Petal width (in cm)     2.4
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values('Petal width (in cm)',axis=0)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  ...           Class  SepalExtra
# 32                    5.2                  4.1  ...     Iris-setosa       21.32
# 13                    4.3                  3.0  ...     Iris-setosa       12.90
# 37                    4.9                  3.1  ...     Iris-setosa       15.19
# 9                     4.9                  3.1  ...     Iris-setosa       15.19
# 12                    4.8                  3.0  ...     Iris-setosa       14.40
# 34                    4.9                  3.1  ...     Iris-setosa       15.19
# 0                     5.1                  3.5  ...     Iris-setosa       17.85
# 27                    5.2                  3.5  ...     Iris-setosa       18.20
# 28                    5.2                  3.4  ...     Iris-setosa       17.68
# 29                    4.7                  3.2  ...     Iris-setosa       15.04
# 30                    4.8                  3.1  ...     Iris-setosa       14.88
# 33                    5.5                  4.2  ...     Iris-setosa       23.10
# 36                    5.5                  3.5  ...     Iris-setosa       19.25
# 38                    4.4                  3.0  ...     Iris-setosa       13.20
# 39                    5.1                  3.4  ...     Iris-setosa       17.34
# 42                    4.4                  3.2  ...     Iris-setosa       14.08
# 46                    5.1                  3.8  ...     Iris-setosa       19.38
# 47                    4.6                  3.2  ...     Iris-setosa       14.72
# 48                    5.3                  3.7  ...     Iris-setosa       19.61
# 49                    5.0                  3.3  ...     Iris-setosa       16.50
# 25                    5.0                  3.0  ...     Iris-setosa       15.00
# 24                    4.8                  3.4  ...     Iris-setosa       16.32
# 35                    5.0                  3.2  ...     Iris-setosa       16.00
# 3                     4.6                  3.1  ...     Iris-setosa       14.26
# 2                     4.7                  3.2  ...     Iris-setosa       15.04
# 7                     5.0                  3.4  ...     Iris-setosa       17.00
# 8                     4.4                  2.9  ...     Iris-setosa       12.76
# 10                    5.4                  3.7  ...     Iris-setosa       19.98
# 4                     5.0                  3.6  ...     Iris-setosa       18.00
# 11                    4.8                  3.4  ...     Iris-setosa       16.32
# ..                    ...                  ...  ...             ...         ...
# 111                   6.4                  2.7  ...  Iris-virginica       17.28
# 121                   5.6                  2.8  ...  Iris-virginica       15.68
# 122                   7.7                  2.8  ...  Iris-virginica       21.56
# 147                   6.5                  3.0  ...  Iris-virginica       19.50
# 113                   5.7                  2.5  ...  Iris-virginica       14.25
# 131                   7.9                  3.8  ...  Iris-virginica       30.02
# 110                   6.5                  3.2  ...  Iris-virginica       20.80
# 139                   6.9                  3.1  ...  Iris-virginica       21.39
# 102                   7.1                  3.0  ...  Iris-virginica       21.30
# 112                   6.8                  3.0  ...  Iris-virginica       20.40
# 105                   7.6                  3.0  ...  Iris-virginica       22.80
# 124                   6.7                  3.3  ...  Iris-virginica       22.11
# 128                   6.4                  2.8  ...  Iris-virginica       17.92
# 117                   7.7                  3.8  ...  Iris-virginica       29.26
# 132                   6.4                  2.8  ...  Iris-virginica       17.92
# 104                   6.5                  3.0  ...  Iris-virginica       19.50
# 120                   6.9                  3.2  ...  Iris-virginica       22.08
# 115                   6.4                  3.2  ...  Iris-virginica       20.48
# 148                   6.2                  3.4  ...  Iris-virginica       21.08
# 141                   6.9                  3.1  ...  Iris-virginica       21.39
# 143                   6.8                  3.2  ...  Iris-virginica       21.76
# 145                   6.7                  3.0  ...  Iris-virginica       20.10
# 118                   7.7                  2.6  ...  Iris-virginica       20.02
# 135                   7.7                  3.0  ...  Iris-virginica       23.10
# 136                   6.3                  3.4  ...  Iris-virginica       21.42
# 140                   6.7                  3.1  ...  Iris-virginica       20.77
# 114                   5.8                  2.8  ...  Iris-virginica       16.24
# 100                   6.3                  3.3  ...  Iris-virginica       20.79
# 144                   6.7                  3.3  ...  Iris-virginica       22.11
# 109                   7.2                  3.6  ...  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop(['SepalExtra'], axis=1, inplace=True)

# %%
iris.head(2)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
#
# [2 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#iris.iloc[0:10][['Sepal Length (in cm)','Sepal Width in (cm)']]
IrisSubset=iris.iloc[0:10][iris.columns[0:3]]

# %%
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
hrData=pd.read_csv('/content/drive/My Drive/Colab Notebooks/R1L2/HR_external.txt',delimiter='\t')
hrData.head()
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
# 2        Ind3       Yes  ...                        0                     0
# 3        Ind4        No  ...                        3                     0
# 4        Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hrData.shape

#(Rows,columns)
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hrData.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
hrData.head(2)
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hrData.columns.tolist()[2:10]
#[0:3]

#'Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
# Out:
# ['Age',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount']

# %%
hrData[hrData.columns.tolist()[2:10]]
# Out:
#       Age  BusinessTravel  DailyRate  ...  Education  EducationField  EmployeeCount
# 0      41               1       1102  ...          2               1              1
# 1      49               2        279  ...          1               1              1
# 2      37               1       1373  ...          2               6              1
# 3      33               2       1392  ...          4               1              1
# 4      27               1        591  ...          1               2              1
# 5      32               2       1005  ...          2               1              1
# 6      59               1       1324  ...          3               2              1
# 7      30               1       1358  ...          1               1              1
# 8      38               2        216  ...          3               1              1
# 9      36               1       1299  ...          3               2              1
# 10     35               1        809  ...          3               2              1
# 11     29               1        153  ...          2               1              1
# 12     31               1        670  ...          1               1              1
# 13     34               1       1346  ...          2               2              1
# 14     28               1        103  ...          3               1              1
# 15     29               1       1389  ...          4               1              1
# 16     32               1        334  ...          2               1              1
# 17     22               3       1123  ...          2               2              1
# 18     53               1       1219  ...          4               1              1
# 19     38               1        371  ...          3               1              1
# 20     24               3        673  ...          2               6              1
# 21     36               1       1218  ...          4               1              1
# 22     34               1        419  ...          4               1              1
# 23     21               1        391  ...          2               1              1
# 24     34               1        699  ...          1               2              1
# 25     53               1       1282  ...          3               6              1
# 26     32               2       1125  ...          1               1              1
# 27     42               1        691  ...          4               3              1
# 28     44               1        477  ...          4               2              1
# 29     46               1        705  ...          4               3              1
# ...   ...             ...        ...  ...        ...             ...            ...
# 1440   36               2        688  ...          2               1              1
# 1441   56               3        667  ...          4               1              1
# 1442   29               1       1092  ...          4               2              1
# 1443   42               1        300  ...          3               1              1
# 1444   56               1        310  ...          2               4              1
# 1445   41               1        582  ...          4               1              1
# 1446   34               1        704  ...          3               3              1
# 1447   36               3        301  ...          4               3              1
# 1448   41               1        930  ...          3               1              1
# 1449   32               1        529  ...          3               4              1
# 1450   35               1       1146  ...          4               1              1
# 1451   38               1        345  ...          2               1              1
# 1452   50               2        878  ...          4               1              1
# 1453   36               1       1120  ...          4               3              1
# 1454   45               1        374  ...          3               1              1
# 1455   40               1       1322  ...          4               1              1
# 1456   35               2       1199  ...          4               1              1
# 1457   40               1       1194  ...          4               2              1
# 1458   35               1        287  ...          4               1              1
# 1459   29               1       1378  ...          2               6              1
# 1460   29               1        468  ...          4               2              1
# 1461   50               1        410  ...          3               3              1
# 1462   39               1        722  ...          1               3              1
# 1463   31               3        325  ...          3               2              1
# 1464   26               1       1167  ...          3               6              1
# 1465   36               2        884  ...          2               2              1
# 1466   39               1        613  ...          1               2              1
# 1467   27               1        155  ...          3               1              1
# 1468   49               2       1023  ...          3               2              1
# 1469   34               1        628  ...          3               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hrData.head(5)
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
# 2        Ind3       Yes  ...                        0                     0
# 3        Ind4        No  ...                        3                     0
# 4        Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %%
# Male is marked as 1 and Female as 2

print('Male Count:',hrData['Gender'].tolist().count(1),'    Female Count: ', hrData['Gender'].tolist().count(2))


#hrData
# Out:
# Male Count: 882     Female Count:  588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Q3,Q1=hrData['Age'].quantile([.75,.25])
print('IQR: ', Q3-Q1)
# Out:
# IQR:  13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
drDF=hrData['DailyRate']
print('Mean: ', drDF.mean(), '  Median: ', drDF.median(), ' Variance: ' , drDF.var())
# Out:
# Mean:  802.4857142857143   Median:  802.0  Variance:  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#hrData['Attrition'].hist(figsize=(5,10))
#hrData.Attrition.plot.hist()
newHR = hrData.replace('Yes',1)
newHR = newHR.replace('No',0)
#newHR.Attrition.plot.hist()
newHR['Attrition'].hist(figsize=(5,10))

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.plot(hrData['TotalWorkingYears'],'*')
